# %%
import requests 
import pymongo
import time
from datetime import datetime

# %%
url = 'http://api.citybik.es/v2/networks/bicicorunha'

# %%
respone = requests.get(url)

# %%
data = respone.json()
data
# Out:
# {'network': {'id': 'bicicorunha',
#   'name': 'Bicicoruña',
#   'location': {'latitude': 43.3623,
#    'longitude': -8.4115,
#    'city': 'A Coruña',
#    'country': 'ES'},
#   'href': '/v2/networks/bicicorunha',
#   'company': ['PBSC Urban Solutions'],
#   'gbfs_href': 'https://acoruna.publicbikesystem.net/customer/gbfs/v2/gbfs.json',
#   'stations': [{'id': '023efce1bbb332a1b918d56aeb671890',
#     'name': 'Avenida de Arteixo',
#     'latitude': 43.360755,
#     'longitude': -8.410942,
#     'timestamp': '2024-12-17T22:09:32.128647Z',
#     'free_bikes': 1,
#     'empty_slots': 14,
#     'extra': {'uid': '53',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473172,
#      'address': 'Avenida de Arteixo,29',
#      'post_code': '15007',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '02cecd02915c86d7ab8034b61b19da0e',
#     'name': 'Mercado de Monte Alto',
#     'latitude': 43.378,
#     'longitude': -8.399755,
#     'timestamp': '2024-12-17T22:09:32.128502Z',
#     'free_bikes': 6,
#     'empty_slots': 8,
#     'extra': {'uid': '43',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473250,
#      'address': 'Calle Antonio Santiago',
#      'post_code': '15002',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 3,
#      'ebikes': 3,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '030c4027b0bea390e562645c7082db4c',
#     'name': 'Los Rosales',
#     'latitude': 43.3743246,
#     'longitude': -8.4319872,
#     'timestamp': '2024-12-17T22:09:32.127695Z',
#     'free_bikes': 4,
#     'empty_slots': 21,
#     'extra': {'uid': '11',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471998,
#      'address': 'Rúa Emilio González López, 92',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 25,
#      'normal_bikes': 0,
#      'ebikes': 4,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '0e3aa0134a2f3d07ae5bd093e6af9a33',
#     'name': 'Plaza de Portugal',
#     'latitude': 43.3685842,
#     'longitude': -8.414535,
#     'timestamp': '2024-12-17T22:09:32.128679Z',
#     'free_bikes': 0,
#     'empty_slots': 20,
#     'extra': {'uid': '55',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473174,
#      'address': 'Av. Habana, S.N',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 20,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '104e0797759d11ac22a61cfed357800b',
#     'name': 'Ventorrillo',
#     'latitude': 43.359323,
#     'longitude': -8.422561,
#     'timestamp': '2024-12-17T22:09:32.128162Z',
#     'free_bikes': 11,
#     'empty_slots': 7,
#     'extra': {'uid': '27',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473172,
#      'address': 'Plaza Ventorrillo, 0 ',
#      'post_code': '15010',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 18,
#      'normal_bikes': 7,
#      'ebikes': 4,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '10af3b0e504fc241415d4047a58bfb5b',
#     'name': 'Cd Castrillón',
#     'latitude': 43.349334477951,
#     'longitude': -8.398615367597959,
#     'timestamp': '2024-12-17T22:09:32.128090Z',
#     'free_bikes': 6,
#     'empty_slots': 9,
#     'extra': {'uid': '23',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473188,
#      'address': 'Av. Casanova de Eirís',
#      'post_code': '15009',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 5,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '15b6693701eb534cddabc0bdd4c3b8a2',
#     'name': ' Pablo Picasso',
#     'latitude': 43.346126,
#     'longitude': -8.410817,
#     'timestamp': '2024-12-17T22:09:32.128127Z',
#     'free_bikes': 10,
#     'empty_slots': 9,
#     'extra': {'uid': '25',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734472043,
#      'address': 'Calle Pintor Luis  Mosquera, 2',
#      'post_code': '15008',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '16d30b6bb080c9ceac0ab0ca3b20111a',
#     'name': 'Barrio de las Flores',
#     'latitude': 43.346372,
#     'longitude': -8.403369,
#     'timestamp': '2024-12-17T22:09:32.128336Z',
#     'free_bikes': 10,
#     'empty_slots': 13,
#     'extra': {'uid': '31',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471934,
#      'address': 'Plaza Fresnos s/n',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '18b3d4c21c5cec9d8e25fa0a6cab109a',
#     'name': 'Torre de Hércules',
#     'latitude': 43.3833583,
#     'longitude': -8.4020407,
#     'timestamp': '2024-12-17T22:09:32.127589Z',
#     'free_bikes': 5,
#     'empty_slots': 10,
#     'extra': {'uid': '5',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471921,
#      'address': 'P.º Marítimo Alcalde Francisco Vázquez, 151',
#      'post_code': '15002',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 4,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '18e32269ce7f371acf5ca7f016b07a2a',
#     'name': 'Campo de Marte',
#     'latitude': 43.3758149,
#     'longitude': -8.3984484,
#     'timestamp': '2024-12-17T22:09:32.127987Z',
#     'free_bikes': 5,
#     'empty_slots': 10,
#     'extra': {'uid': '17',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473296,
#      'address': 'Parque Marte, 1T  ',
#      'post_code': '15002',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 2,
#      'ebikes': 3,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '198820c7b5fc5681e896110c4383a4a0',
#     'name': 'Hospital Abente y Lago',
#     'latitude': 43.36874508285373,
#     'longitude': -8.390026720523842,
#     'timestamp': '2024-12-17T22:09:32.128484Z',
#     'free_bikes': 1,
#     'empty_slots': 14,
#     'extra': {'uid': '42',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473310,
#      'address': 'Calle San Francisco, s/n',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 0,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '1a77b47ff9c828307610737e1a9046c3',
#     'name': 'Plaza de Tabacos',
#     'latitude': 43.356628603246214,
#     'longitude': -8.40148645853997,
#     'timestamp': '2024-12-17T22:09:32.127936Z',
#     'free_bikes': 6,
#     'empty_slots': 13,
#     'extra': {'uid': '14',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473272,
#      'address': 'Calle Abogacía, Pl. Fabrica de Tabacos, 5 ',
#      'post_code': '15006',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 6,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '1df27d4197c65e404466107444967600',
#     'name': 'Casa del Agua',
#     'latitude': 43.3689494,
#     'longitude': -8.4197601,
#     'timestamp': '2024-12-17T22:09:32.128711Z',
#     'free_bikes': 0,
#     'empty_slots': 14,
#     'extra': {'uid': '57',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473169,
#      'address': 'Manuel Murguía',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 16,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '2139f0834a27ab807a5edb3420c2841e',
#     'name': 'Plaza De Pontevedra',
#     'latitude': 43.3680112,
#     'longitude': -8.4066505,
#     'timestamp': '2024-12-17T22:09:32.127540Z',
#     'free_bikes': 10,
#     'empty_slots': 18,
#     'extra': {'uid': '3',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473218,
#      'address': 'R. San Andrés, 164',
#      'post_code': '15003',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 29,
#      'normal_bikes': 8,
#      'ebikes': 2,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '280380564f13b15dbc782a43d2426689',
#     'name': 'Estación Autobuses',
#     'latitude': 43.353622,
#     'longitude': -8.4059565,
#     'timestamp': '2024-12-17T22:09:32.127642Z',
#     'free_bikes': 1,
#     'empty_slots': 14,
#     'extra': {'uid': '8',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473331,
#      'address': 'E.A, Estación de Autobuses de, Rúa Caballeros, 21',
#      'post_code': '15009',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '2ad08bdfd5fda295855b0297d410716f',
#     'name': 'Orillamar',
#     'latitude': 43.375706,
#     'longitude': -8.395765,
#     'timestamp': '2024-12-17T22:09:32.128447Z',
#     'free_bikes': 6,
#     'empty_slots': 9,
#     'extra': {'uid': '40',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473215,
#      'address': 'Rúa Orillamar, 37',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 5,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '2cdf0b7a087c888dee45f8c619ea5bb2',
#     'name': 'Aquarium',
#     'latitude': 43.3812011,
#     'longitude': -8.4099486,
#     'timestamp': '2024-12-17T22:09:32.127567Z',
#     'free_bikes': 11,
#     'empty_slots': 2,
#     'extra': {'uid': '4',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473199,
#      'address': 'P.º Marítimo Alcalde Francisco Vázquez, 59',
#      'post_code': '15002',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 11,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '2d16841278003915e01f897638776f63',
#     'name': 'Parque de Oza',
#     'latitude': 43.351613,
#     'longitude': -8.401781,
#     'timestamp': '2024-12-17T22:09:32.128581Z',
#     'free_bikes': 10,
#     'empty_slots': 5,
#     'extra': {'uid': '49',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471942,
#      'address': 'Rda. de Outeiro, 68 ',
#      'post_code': '15009',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '305b3112f5f1083876b2ce9146742596',
#     'name': 'Aparcamiento Matogrande',
#     'latitude': 43.34080343343825,
#     'longitude': -8.404671581745156,
#     'timestamp': '2024-12-17T22:09:32.127953Z',
#     'free_bikes': 12,
#     'empty_slots': 3,
#     'extra': {'uid': '15',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473165,
#      'address': 'R. Enrique Mariñas Romero',
#      'post_code': '15009',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 6,
#      'ebikes': 6,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '447505d0e57db2f71d7572ceedcbb046',
#     'name': 'Agrela',
#     'latitude': 43.354365513765316,
#     'longitude': -8.422193301049806,
#     'timestamp': '2024-12-17T22:09:32.128282Z',
#     'free_bikes': 7,
#     'empty_slots': 16,
#     'extra': {'uid': '28',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473214,
#      'address': 'Rúa Gutemberg, 16 ',
#      'post_code': '15008',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 6,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '4c0262f67097091b43ca54b09a072bce',
#     'name': 'Paseo de Los Puentes',
#     'latitude': 43.364594,
#     'longitude': -8.4157724,
#     'timestamp': '2024-12-17T22:09:32.128040Z',
#     'free_bikes': 2,
#     'empty_slots': 17,
#     'extra': {'uid': '20',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473247,
#      'address': 'P.º de los Puentes, 9',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '5053bbeb34b876b59c45121ab341af93',
#     'name': 'Ágora',
#     'latitude': 43.363261912647694,
#     'longitude': -8.427038522720345,
#     'timestamp': '2024-12-17T22:09:32.128518Z',
#     'free_bikes': 1,
#     'empty_slots': 21,
#     'extra': {'uid': '44',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473318,
#      'address': 'R. Ágora, 17 ',
#      'post_code': '15010',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 0,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '5330f247a28be53b762427542867dd73',
#     'name': 'Campo de La Leña (Plaza De España)',
#     'latitude': 43.3725483,
#     'longitude': -8.3956685,
#     'timestamp': '2024-12-17T22:09:32.128005Z',
#     'free_bikes': 6,
#     'empty_slots': 8,
#     'extra': {'uid': '18',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473306,
#      'address': 'Costa San Agustín, 4 ',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 4,
#      'ebikes': 2,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '7446dcc290f2570a47d4ed2bc9282ceb',
#     'name': 'Cuatro Caminos',
#     'latitude': 43.35662,
#     'longitude': -8.40617,
#     'timestamp': '2024-12-17T22:09:32.128597Z',
#     'free_bikes': 3,
#     'empty_slots': 18,
#     'extra': {'uid': '50',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473168,
#      'address': 'Rùa Fernando Rey,frente nº8',
#      'post_code': '15006',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 3,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '75e54fb28a5679603047bbd282047916',
#     'name': 'Puerto - Palexco',
#     'latitude': 43.3690021,
#     'longitude': -8.3988155,
#     'timestamp': '2024-12-17T22:09:32.127607Z',
#     'free_bikes': 9,
#     'empty_slots': 5,
#     'extra': {'uid': '6',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473231,
#      'address': 'Rúa Celedonio de Uribe, 2',
#      'post_code': '15006',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '88a676510bd52100c911fb1a9b5f87b4',
#     'name': 'Expocoruna',
#     'latitude': 43.3389282,
#     'longitude': -8.411651,
#     'timestamp': '2024-12-17T22:09:32.128369Z',
#     'free_bikes': 5,
#     'empty_slots': 12,
#     'extra': {'uid': '33',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471962,
#      'address': 'Av. de la Universidad, 13  ',
#      'post_code': '15008',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 5,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '8c078d095787b97917c07ab40bf3594e',
#     'name': 'Plaza Recife',
#     'latitude': 43.364695,
#     'longitude': -8.409952,
#     'timestamp': '2024-12-17T22:09:32.128565Z',
#     'free_bikes': 9,
#     'empty_slots': 6,
#     'extra': {'uid': '47',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473340,
#      'address': 'Rúa Magistrado Manuel Artime, 18  ',
#      'post_code': '15004',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 8,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '8dfd4b95e7f499296e03312c5b1f9e22',
#     'name': 'Plaza de San Rosendo',
#     'latitude': 43.3567846,
#     'longitude': -8.4146024,
#     'timestamp': '2024-12-17T22:09:32.128022Z',
#     'free_bikes': 7,
#     'empty_slots': 8,
#     'extra': {'uid': '19',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473222,
#      'address': 'Rúa Alberto Datas Panero, 3 ',
#      'post_code': '15007',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 2,
#      'ebikes': 5,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '938a003c099dc9b2c7411f2000b88022',
#     'name': 'Puerta Real',
#     'latitude': 43.3698168,
#     'longitude': -8.3957142,
#     'timestamp': '2024-12-17T22:09:32.128073Z',
#     'free_bikes': 10,
#     'empty_slots': 12,
#     'extra': {'uid': '22',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473205,
#      'address': 'Rúa Santiago, 2',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '95a1abdf86ec8d29deb7380938c2e02e',
#     'name': 'Plaza de Conchiñas',
#     'latitude': 43.3615047,
#     'longitude': -8.4199767,
#     'timestamp': '2024-12-17T22:09:32.127714Z',
#     'free_bikes': 2,
#     'empty_slots': 11,
#     'extra': {'uid': '12',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473314,
#      'address': 'Rúa Entrepeñas, 2 ',
#      'post_code': '15010',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 1,
#      'ebikes': 2,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '9ba72d8f143fb690546e6950b2d53c97',
#     'name': 'Estación Tren',
#     'latitude': 43.3528011,
#     'longitude': -8.4091132,
#     'timestamp': '2024-12-17T22:09:32.127659Z',
#     'free_bikes': 1,
#     'empty_slots': 13,
#     'extra': {'uid': '9',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734472054,
#      'address': 'Parking Saba Estación de Tren A Coruña',
#      'post_code': '15007',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '9e7f93baecab42d934a507a9ef7e5938',
#     'name': 'Adormideras',
#     'latitude': 43.38337475533955,
#     'longitude': -8.39564819014358,
#     'timestamp': '2024-12-17T22:09:32.128144Z',
#     'free_bikes': 8,
#     'empty_slots': 10,
#     'extra': {'uid': '26',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471979,
#      'address': 'Rúa Juan Sebastián Elcano, 21',
#      'post_code': '15002',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 5,
#      'ebikes': 3,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': '9e84dc079b6d308cb74dedeb0f98f345',
#     'name': 'Marineda',
#     'latitude': 43.34621646271046,
#     'longitude': -8.427290650367745,
#     'timestamp': '2024-12-17T22:09:32.128302Z',
#     'free_bikes': 4,
#     'empty_slots': 18,
#     'extra': {'uid': '29',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473243,
#      'address': 'Camiño Grela al Martinete',
#      'post_code': '15008',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'a2893fa94f1de9a32b0b210b994f3e10',
#     'name': 'Parque de Santa Margarita',
#     'latitude': 43.3602003,
#     'longitude': -8.4150145,
#     'timestamp': '2024-12-17T22:09:32.128663Z',
#     'free_bikes': 2,
#     'empty_slots': 9,
#     'extra': {'uid': '54',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471981,
#      'address': 'Rda. Nelle, 94',
#      'post_code': '15005',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 13,
#      'normal_bikes': 1,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'a876e4f21fbf7e9873b395485d080c1f',
#     'name': 'Ciudad Escolar',
#     'latitude': 43.37110620280361,
#     'longitude': -8.421887669697579,
#     'timestamp': '2024-12-17T22:09:32.128399Z',
#     'free_bikes': 8,
#     'empty_slots': 11,
#     'extra': {'uid': '36',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473183,
#      'address': 'Av. Gran Canaria, 2',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 8,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'b376679bc7b9464f8f0edc775d71d5ad',
#     'name': 'Parque de Eirís',
#     'latitude': 43.34467,
#     'longitude': -8.39535,
#     'timestamp': '2024-12-17T22:09:32.128352Z',
#     'free_bikes': 4,
#     'empty_slots': 15,
#     'extra': {'uid': '32',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473311,
#      'address': 'A. de lamadosa e Rúa Eirís de Arriba',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 3,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'b55aa9b4a84ef790d95fe5c43e4bd1ad',
#     'name': 'Novo Mesoiro',
#     'latitude': 43.326056379134286,
#     'longitude': -8.432357918554677,
#     'timestamp': '2024-12-17T22:09:32.128319Z',
#     'free_bikes': 3,
#     'empty_slots': 20,
#     'extra': {'uid': '30',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473197,
#      'address': 'Avenida Novo Mesoiro',
#      'post_code': '15190',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 2,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'bf735b3d92053c97f825a333f6686aac',
#     'name': 'Chuac',
#     'latitude': 43.34593,
#     'longitude': -8.390224,
#     'timestamp': '2024-12-17T22:09:32.128614Z',
#     'free_bikes': 4,
#     'empty_slots': 15,
#     'extra': {'uid': '51',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473276,
#      'address': 'Calle A, 12D  ',
#      'post_code': '15009',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 4,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'c158d9e1e35d2323bb2bbf49da32c47b',
#     'name': 'Casa de Sol',
#     'latitude': 43.372345,
#     'longitude': -8.4028996,
#     'timestamp': '2024-12-17T22:09:32.127970Z',
#     'free_bikes': 11,
#     'empty_slots': 5,
#     'extra': {'uid': '16',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473240,
#      'address': 'Rúa Sol, 20  ',
#      'post_code': '15003',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 16,
#      'normal_bikes': 10,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'cc7469fb9362066706da43aafbe02e1f',
#     'name': 'Centro deportivo Elviña',
#     'latitude': 43.34181585290314,
#     'longitude': -8.414121004104622,
#     'timestamp': '2024-12-17T22:09:32.128631Z',
#     'free_bikes': 8,
#     'empty_slots': 11,
#     'extra': {'uid': '52',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473202,
#      'address': 'Plaza Agustin Diaz, 5',
#      'post_code': '15008',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 8,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'd03cf3099b20bc41dddaf4ee8b282dfa',
#     'name': 'Maestranza',
#     'latitude': 43.37117,
#     'longitude': -8.3909125,
#     'timestamp': '2024-12-17T22:09:32.128384Z',
#     'free_bikes': 7,
#     'empty_slots': 11,
#     'extra': {'uid': '35',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473211,
#      'address': 'Rúa Maestranza, 9 ',
#      'post_code': '15001',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 7,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'd9b01b13fb85506d591617ab5e8cf4bc',
#     'name': 'Mirador de los Castros',
#     'latitude': 43.3539722,
#     'longitude': -8.3904889,
#     'timestamp': '2024-12-17T22:09:32.127677Z',
#     'free_bikes': 7,
#     'empty_slots': 12,
#     'extra': {'uid': '10',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473294,
#      'address': 'Centro Deportivo San Diego',
#      'post_code': '15007',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 6,
#      'ebikes': 1,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'daa753bf3bdb6d5b722734d126b843b1',
#     'name': 'Plaza de Vigo',
#     'latitude': 43.361634,
#     'longitude': -8.407152,
#     'timestamp': '2024-12-17T22:09:32.127918Z',
#     'free_bikes': 7,
#     'empty_slots': 10,
#     'extra': {'uid': '13',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473346,
#      'address': 'Emilia Pardo Bazán 28-30',
#      'post_code': '15005',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 19,
#      'normal_bikes': 7,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'e97735d79704dc080f7ee1a2af1e402f',
#     'name': 'Obelisco',
#     'latitude': 43.3682065,
#     'longitude': -8.4032216,
#     'timestamp': '2024-12-17T22:09:32.127625Z',
#     'free_bikes': 1,
#     'empty_slots': 20,
#     'extra': {'uid': '7',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473325,
#      'address': 'Rúa Cantón Grande, 4',
#      'post_code': '15003',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 23,
#      'normal_bikes': 1,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'f04ee4ffca2a6f3daacba88a9eee8487',
#     'name': 'Millenium',
#     'latitude': 43.3768118,
#     'longitude': -8.423091,
#     'timestamp': '2024-12-17T22:09:32.128695Z',
#     'free_bikes': 10,
#     'empty_slots': 4,
#     'extra': {'uid': '56',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734471995,
#      'address': 'Av. Gerardo Porto ',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 10,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'f702a7b2b1631ace3781c405acb99b70',
#     'name': 'Praza de Ourense',
#     'latitude': 43.3651583,
#     'longitude': -8.4053212,
#     'timestamp': '2024-12-17T22:09:32.128463Z',
#     'free_bikes': 6,
#     'empty_slots': 9,
#     'extra': {'uid': '41',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473296,
#      'address': 'Praza Ourense, 3  ',
#      'post_code': '15004',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 6,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'f86954a7b51703f735bce5b549cb4e16',
#     'name': 'Parque del Agra',
#     'latitude': 43.36514,
#     'longitude': -8.421649,
#     'timestamp': '2024-12-17T22:09:32.128534Z',
#     'free_bikes': 0,
#     'empty_slots': 15,
#     'extra': {'uid': '45',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473226,
#      'address': 'Calle Canceliña,8',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 0,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'fb0d3f40ea7570546b171b43ccd57a2a',
#     'name': 'Rosales-Labañou',
#     'latitude': 43.37409724254996,
#     'longitude': -8.42479703248882,
#     'timestamp': '2024-12-17T22:09:32.128549Z',
#     'free_bikes': 7,
#     'empty_slots': 8,
#     'extra': {'uid': '46',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473252,
#      'address': 'Rúa Manuel Azaña,2',
#      'post_code': '15011',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 7,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}},
#    {'id': 'fee1ae73b32ffb83e1bf3f6e83e616b7',
#     'name': 'Centro Cívico Monelos',
#     'latitude': 43.3493537,
#     'longitude': -8.4049558,
#     'timestamp': '2024-12-17T22:09:32.128057Z',
#     'free_bikes': 9,
#     'empty_slots': 6,
#     'extra': {'uid': '21',
#      'renting': True,
#      'returning': True,
#      'last_updated': 1734473186,
#      'address': 'Av. Salvador de Madariaga, 2T',
#      'post_code': '15008',
#      'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#      'payment-terminal': True,
#      'altitude': 0.0,
#      'slots': 15,
#      'normal_bikes': 9,
#      'ebikes': 0,
#      'has_ebikes': True,
#      'rental_uris': {}}}]}}

# %%
# Función para obter datos da API
def obtener_datos_api():
    url = "http://api.citybik.es/v2/networks/bicicorunha"  # Substitúe por a URL real da API
    response = requests.get(url)
    if response.status_code == 200:
        try:
            datos = response.json()
            return datos['network']['stations'] # Retorna os datos en formato JSON
        except ValueError:
            print("Erro ao parsear os datos JSON.")
            return None
    else:
        print("Error ao obter datos da API")
        return None

datos = obtener_datos_api()
datos
# Out:
# [{'id': '023efce1bbb332a1b918d56aeb671890',
#   'name': 'Avenida de Arteixo',
#   'latitude': 43.360755,
#   'longitude': -8.410942,
#   'timestamp': '2024-12-17T22:09:32.128647Z',
#   'free_bikes': 1,
#   'empty_slots': 14,
#   'extra': {'uid': '53',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473172,
#    'address': 'Avenida de Arteixo,29',
#    'post_code': '15007',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 1,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '02cecd02915c86d7ab8034b61b19da0e',
#   'name': 'Mercado de Monte Alto',
#   'latitude': 43.378,
#   'longitude': -8.399755,
#   'timestamp': '2024-12-17T22:09:32.128502Z',
#   'free_bikes': 6,
#   'empty_slots': 8,
#   'extra': {'uid': '43',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473250,
#    'address': 'Calle Antonio Santiago',
#    'post_code': '15002',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 3,
#    'ebikes': 3,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '030c4027b0bea390e562645c7082db4c',
#   'name': 'Los Rosales',
#   'latitude': 43.3743246,
#   'longitude': -8.4319872,
#   'timestamp': '2024-12-17T22:09:32.127695Z',
#   'free_bikes': 4,
#   'empty_slots': 21,
#   'extra': {'uid': '11',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471998,
#    'address': 'Rúa Emilio González López, 92',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 25,
#    'normal_bikes': 0,
#    'ebikes': 4,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '0e3aa0134a2f3d07ae5bd093e6af9a33',
#   'name': 'Plaza de Portugal',
#   'latitude': 43.3685842,
#   'longitude': -8.414535,
#   'timestamp': '2024-12-17T22:09:32.128679Z',
#   'free_bikes': 0,
#   'empty_slots': 20,
#   'extra': {'uid': '55',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473174,
#    'address': 'Av. Habana, S.N',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 20,
#    'normal_bikes': 0,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '104e0797759d11ac22a61cfed357800b',
#   'name': 'Ventorrillo',
#   'latitude': 43.359323,
#   'longitude': -8.422561,
#   'timestamp': '2024-12-17T22:09:32.128162Z',
#   'free_bikes': 11,
#   'empty_slots': 7,
#   'extra': {'uid': '27',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473172,
#    'address': 'Plaza Ventorrillo, 0 ',
#    'post_code': '15010',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 18,
#    'normal_bikes': 7,
#    'ebikes': 4,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '10af3b0e504fc241415d4047a58bfb5b',
#   'name': 'Cd Castrillón',
#   'latitude': 43.349334477951,
#   'longitude': -8.398615367597959,
#   'timestamp': '2024-12-17T22:09:32.128090Z',
#   'free_bikes': 6,
#   'empty_slots': 9,
#   'extra': {'uid': '23',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473188,
#    'address': 'Av. Casanova de Eirís',
#    'post_code': '15009',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 5,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '15b6693701eb534cddabc0bdd4c3b8a2',
#   'name': ' Pablo Picasso',
#   'latitude': 43.346126,
#   'longitude': -8.410817,
#   'timestamp': '2024-12-17T22:09:32.128127Z',
#   'free_bikes': 10,
#   'empty_slots': 9,
#   'extra': {'uid': '25',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734472043,
#    'address': 'Calle Pintor Luis  Mosquera, 2',
#    'post_code': '15008',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 10,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '16d30b6bb080c9ceac0ab0ca3b20111a',
#   'name': 'Barrio de las Flores',
#   'latitude': 43.346372,
#   'longitude': -8.403369,
#   'timestamp': '2024-12-17T22:09:32.128336Z',
#   'free_bikes': 10,
#   'empty_slots': 13,
#   'extra': {'uid': '31',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471934,
#    'address': 'Plaza Fresnos s/n',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 10,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '18b3d4c21c5cec9d8e25fa0a6cab109a',
#   'name': 'Torre de Hércules',
#   'latitude': 43.3833583,
#   'longitude': -8.4020407,
#   'timestamp': '2024-12-17T22:09:32.127589Z',
#   'free_bikes': 5,
#   'empty_slots': 10,
#   'extra': {'uid': '5',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471921,
#    'address': 'P.º Marítimo Alcalde Francisco Vázquez, 151',
#    'post_code': '15002',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 4,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '18e32269ce7f371acf5ca7f016b07a2a',
#   'name': 'Campo de Marte',
#   'latitude': 43.3758149,
#   'longitude': -8.3984484,
#   'timestamp': '2024-12-17T22:09:32.127987Z',
#   'free_bikes': 5,
#   'empty_slots': 10,
#   'extra': {'uid': '17',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473296,
#    'address': 'Parque Marte, 1T  ',
#    'post_code': '15002',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 2,
#    'ebikes': 3,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '198820c7b5fc5681e896110c4383a4a0',
#   'name': 'Hospital Abente y Lago',
#   'latitude': 43.36874508285373,
#   'longitude': -8.390026720523842,
#   'timestamp': '2024-12-17T22:09:32.128484Z',
#   'free_bikes': 1,
#   'empty_slots': 14,
#   'extra': {'uid': '42',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473310,
#    'address': 'Calle San Francisco, s/n',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 0,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '1a77b47ff9c828307610737e1a9046c3',
#   'name': 'Plaza de Tabacos',
#   'latitude': 43.356628603246214,
#   'longitude': -8.40148645853997,
#   'timestamp': '2024-12-17T22:09:32.127936Z',
#   'free_bikes': 6,
#   'empty_slots': 13,
#   'extra': {'uid': '14',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473272,
#    'address': 'Calle Abogacía, Pl. Fabrica de Tabacos, 5 ',
#    'post_code': '15006',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 6,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '1df27d4197c65e404466107444967600',
#   'name': 'Casa del Agua',
#   'latitude': 43.3689494,
#   'longitude': -8.4197601,
#   'timestamp': '2024-12-17T22:09:32.128711Z',
#   'free_bikes': 0,
#   'empty_slots': 14,
#   'extra': {'uid': '57',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473169,
#    'address': 'Manuel Murguía',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 16,
#    'normal_bikes': 0,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '2139f0834a27ab807a5edb3420c2841e',
#   'name': 'Plaza De Pontevedra',
#   'latitude': 43.3680112,
#   'longitude': -8.4066505,
#   'timestamp': '2024-12-17T22:09:32.127540Z',
#   'free_bikes': 10,
#   'empty_slots': 18,
#   'extra': {'uid': '3',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473218,
#    'address': 'R. San Andrés, 164',
#    'post_code': '15003',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 29,
#    'normal_bikes': 8,
#    'ebikes': 2,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '280380564f13b15dbc782a43d2426689',
#   'name': 'Estación Autobuses',
#   'latitude': 43.353622,
#   'longitude': -8.4059565,
#   'timestamp': '2024-12-17T22:09:32.127642Z',
#   'free_bikes': 1,
#   'empty_slots': 14,
#   'extra': {'uid': '8',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473331,
#    'address': 'E.A, Estación de Autobuses de, Rúa Caballeros, 21',
#    'post_code': '15009',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 1,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '2ad08bdfd5fda295855b0297d410716f',
#   'name': 'Orillamar',
#   'latitude': 43.375706,
#   'longitude': -8.395765,
#   'timestamp': '2024-12-17T22:09:32.128447Z',
#   'free_bikes': 6,
#   'empty_slots': 9,
#   'extra': {'uid': '40',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473215,
#    'address': 'Rúa Orillamar, 37',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 5,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '2cdf0b7a087c888dee45f8c619ea5bb2',
#   'name': 'Aquarium',
#   'latitude': 43.3812011,
#   'longitude': -8.4099486,
#   'timestamp': '2024-12-17T22:09:32.127567Z',
#   'free_bikes': 11,
#   'empty_slots': 2,
#   'extra': {'uid': '4',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473199,
#    'address': 'P.º Marítimo Alcalde Francisco Vázquez, 59',
#    'post_code': '15002',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 11,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '2d16841278003915e01f897638776f63',
#   'name': 'Parque de Oza',
#   'latitude': 43.351613,
#   'longitude': -8.401781,
#   'timestamp': '2024-12-17T22:09:32.128581Z',
#   'free_bikes': 10,
#   'empty_slots': 5,
#   'extra': {'uid': '49',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471942,
#    'address': 'Rda. de Outeiro, 68 ',
#    'post_code': '15009',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 10,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '305b3112f5f1083876b2ce9146742596',
#   'name': 'Aparcamiento Matogrande',
#   'latitude': 43.34080343343825,
#   'longitude': -8.404671581745156,
#   'timestamp': '2024-12-17T22:09:32.127953Z',
#   'free_bikes': 12,
#   'empty_slots': 3,
#   'extra': {'uid': '15',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473165,
#    'address': 'R. Enrique Mariñas Romero',
#    'post_code': '15009',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 6,
#    'ebikes': 6,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '447505d0e57db2f71d7572ceedcbb046',
#   'name': 'Agrela',
#   'latitude': 43.354365513765316,
#   'longitude': -8.422193301049806,
#   'timestamp': '2024-12-17T22:09:32.128282Z',
#   'free_bikes': 7,
#   'empty_slots': 16,
#   'extra': {'uid': '28',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473214,
#    'address': 'Rúa Gutemberg, 16 ',
#    'post_code': '15008',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 6,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '4c0262f67097091b43ca54b09a072bce',
#   'name': 'Paseo de Los Puentes',
#   'latitude': 43.364594,
#   'longitude': -8.4157724,
#   'timestamp': '2024-12-17T22:09:32.128040Z',
#   'free_bikes': 2,
#   'empty_slots': 17,
#   'extra': {'uid': '20',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473247,
#    'address': 'P.º de los Puentes, 9',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 1,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '5053bbeb34b876b59c45121ab341af93',
#   'name': 'Ágora',
#   'latitude': 43.363261912647694,
#   'longitude': -8.427038522720345,
#   'timestamp': '2024-12-17T22:09:32.128518Z',
#   'free_bikes': 1,
#   'empty_slots': 21,
#   'extra': {'uid': '44',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473318,
#    'address': 'R. Ágora, 17 ',
#    'post_code': '15010',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 0,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '5330f247a28be53b762427542867dd73',
#   'name': 'Campo de La Leña (Plaza De España)',
#   'latitude': 43.3725483,
#   'longitude': -8.3956685,
#   'timestamp': '2024-12-17T22:09:32.128005Z',
#   'free_bikes': 6,
#   'empty_slots': 8,
#   'extra': {'uid': '18',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473306,
#    'address': 'Costa San Agustín, 4 ',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 4,
#    'ebikes': 2,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '7446dcc290f2570a47d4ed2bc9282ceb',
#   'name': 'Cuatro Caminos',
#   'latitude': 43.35662,
#   'longitude': -8.40617,
#   'timestamp': '2024-12-17T22:09:32.128597Z',
#   'free_bikes': 3,
#   'empty_slots': 18,
#   'extra': {'uid': '50',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473168,
#    'address': 'Rùa Fernando Rey,frente nº8',
#    'post_code': '15006',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 3,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '75e54fb28a5679603047bbd282047916',
#   'name': 'Puerto - Palexco',
#   'latitude': 43.3690021,
#   'longitude': -8.3988155,
#   'timestamp': '2024-12-17T22:09:32.127607Z',
#   'free_bikes': 9,
#   'empty_slots': 5,
#   'extra': {'uid': '6',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473231,
#    'address': 'Rúa Celedonio de Uribe, 2',
#    'post_code': '15006',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 10,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '88a676510bd52100c911fb1a9b5f87b4',
#   'name': 'Expocoruna',
#   'latitude': 43.3389282,
#   'longitude': -8.411651,
#   'timestamp': '2024-12-17T22:09:32.128369Z',
#   'free_bikes': 5,
#   'empty_slots': 12,
#   'extra': {'uid': '33',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471962,
#    'address': 'Av. de la Universidad, 13  ',
#    'post_code': '15008',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 5,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '8c078d095787b97917c07ab40bf3594e',
#   'name': 'Plaza Recife',
#   'latitude': 43.364695,
#   'longitude': -8.409952,
#   'timestamp': '2024-12-17T22:09:32.128565Z',
#   'free_bikes': 9,
#   'empty_slots': 6,
#   'extra': {'uid': '47',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473340,
#    'address': 'Rúa Magistrado Manuel Artime, 18  ',
#    'post_code': '15004',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 8,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '8dfd4b95e7f499296e03312c5b1f9e22',
#   'name': 'Plaza de San Rosendo',
#   'latitude': 43.3567846,
#   'longitude': -8.4146024,
#   'timestamp': '2024-12-17T22:09:32.128022Z',
#   'free_bikes': 7,
#   'empty_slots': 8,
#   'extra': {'uid': '19',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473222,
#    'address': 'Rúa Alberto Datas Panero, 3 ',
#    'post_code': '15007',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 2,
#    'ebikes': 5,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '938a003c099dc9b2c7411f2000b88022',
#   'name': 'Puerta Real',
#   'latitude': 43.3698168,
#   'longitude': -8.3957142,
#   'timestamp': '2024-12-17T22:09:32.128073Z',
#   'free_bikes': 10,
#   'empty_slots': 12,
#   'extra': {'uid': '22',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473205,
#    'address': 'Rúa Santiago, 2',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 10,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '95a1abdf86ec8d29deb7380938c2e02e',
#   'name': 'Plaza de Conchiñas',
#   'latitude': 43.3615047,
#   'longitude': -8.4199767,
#   'timestamp': '2024-12-17T22:09:32.127714Z',
#   'free_bikes': 2,
#   'empty_slots': 11,
#   'extra': {'uid': '12',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473314,
#    'address': 'Rúa Entrepeñas, 2 ',
#    'post_code': '15010',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 1,
#    'ebikes': 2,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '9ba72d8f143fb690546e6950b2d53c97',
#   'name': 'Estación Tren',
#   'latitude': 43.3528011,
#   'longitude': -8.4091132,
#   'timestamp': '2024-12-17T22:09:32.127659Z',
#   'free_bikes': 1,
#   'empty_slots': 13,
#   'extra': {'uid': '9',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734472054,
#    'address': 'Parking Saba Estación de Tren A Coruña',
#    'post_code': '15007',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 1,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '9e7f93baecab42d934a507a9ef7e5938',
#   'name': 'Adormideras',
#   'latitude': 43.38337475533955,
#   'longitude': -8.39564819014358,
#   'timestamp': '2024-12-17T22:09:32.128144Z',
#   'free_bikes': 8,
#   'empty_slots': 10,
#   'extra': {'uid': '26',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471979,
#    'address': 'Rúa Juan Sebastián Elcano, 21',
#    'post_code': '15002',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 5,
#    'ebikes': 3,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': '9e84dc079b6d308cb74dedeb0f98f345',
#   'name': 'Marineda',
#   'latitude': 43.34621646271046,
#   'longitude': -8.427290650367745,
#   'timestamp': '2024-12-17T22:09:32.128302Z',
#   'free_bikes': 4,
#   'empty_slots': 18,
#   'extra': {'uid': '29',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473243,
#    'address': 'Camiño Grela al Martinete',
#    'post_code': '15008',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 4,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'a2893fa94f1de9a32b0b210b994f3e10',
#   'name': 'Parque de Santa Margarita',
#   'latitude': 43.3602003,
#   'longitude': -8.4150145,
#   'timestamp': '2024-12-17T22:09:32.128663Z',
#   'free_bikes': 2,
#   'empty_slots': 9,
#   'extra': {'uid': '54',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471981,
#    'address': 'Rda. Nelle, 94',
#    'post_code': '15005',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 13,
#    'normal_bikes': 1,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'a876e4f21fbf7e9873b395485d080c1f',
#   'name': 'Ciudad Escolar',
#   'latitude': 43.37110620280361,
#   'longitude': -8.421887669697579,
#   'timestamp': '2024-12-17T22:09:32.128399Z',
#   'free_bikes': 8,
#   'empty_slots': 11,
#   'extra': {'uid': '36',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473183,
#    'address': 'Av. Gran Canaria, 2',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 8,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'b376679bc7b9464f8f0edc775d71d5ad',
#   'name': 'Parque de Eirís',
#   'latitude': 43.34467,
#   'longitude': -8.39535,
#   'timestamp': '2024-12-17T22:09:32.128352Z',
#   'free_bikes': 4,
#   'empty_slots': 15,
#   'extra': {'uid': '32',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473311,
#    'address': 'A. de lamadosa e Rúa Eirís de Arriba',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 3,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'b55aa9b4a84ef790d95fe5c43e4bd1ad',
#   'name': 'Novo Mesoiro',
#   'latitude': 43.326056379134286,
#   'longitude': -8.432357918554677,
#   'timestamp': '2024-12-17T22:09:32.128319Z',
#   'free_bikes': 3,
#   'empty_slots': 20,
#   'extra': {'uid': '30',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473197,
#    'address': 'Avenida Novo Mesoiro',
#    'post_code': '15190',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 2,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'bf735b3d92053c97f825a333f6686aac',
#   'name': 'Chuac',
#   'latitude': 43.34593,
#   'longitude': -8.390224,
#   'timestamp': '2024-12-17T22:09:32.128614Z',
#   'free_bikes': 4,
#   'empty_slots': 15,
#   'extra': {'uid': '51',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473276,
#    'address': 'Calle A, 12D  ',
#    'post_code': '15009',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 4,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'c158d9e1e35d2323bb2bbf49da32c47b',
#   'name': 'Casa de Sol',
#   'latitude': 43.372345,
#   'longitude': -8.4028996,
#   'timestamp': '2024-12-17T22:09:32.127970Z',
#   'free_bikes': 11,
#   'empty_slots': 5,
#   'extra': {'uid': '16',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473240,
#    'address': 'Rúa Sol, 20  ',
#    'post_code': '15003',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 16,
#    'normal_bikes': 10,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'cc7469fb9362066706da43aafbe02e1f',
#   'name': 'Centro deportivo Elviña',
#   'latitude': 43.34181585290314,
#   'longitude': -8.414121004104622,
#   'timestamp': '2024-12-17T22:09:32.128631Z',
#   'free_bikes': 8,
#   'empty_slots': 11,
#   'extra': {'uid': '52',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473202,
#    'address': 'Plaza Agustin Diaz, 5',
#    'post_code': '15008',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 8,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'd03cf3099b20bc41dddaf4ee8b282dfa',
#   'name': 'Maestranza',
#   'latitude': 43.37117,
#   'longitude': -8.3909125,
#   'timestamp': '2024-12-17T22:09:32.128384Z',
#   'free_bikes': 7,
#   'empty_slots': 11,
#   'extra': {'uid': '35',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473211,
#    'address': 'Rúa Maestranza, 9 ',
#    'post_code': '15001',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 7,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'd9b01b13fb85506d591617ab5e8cf4bc',
#   'name': 'Mirador de los Castros',
#   'latitude': 43.3539722,
#   'longitude': -8.3904889,
#   'timestamp': '2024-12-17T22:09:32.127677Z',
#   'free_bikes': 7,
#   'empty_slots': 12,
#   'extra': {'uid': '10',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473294,
#    'address': 'Centro Deportivo San Diego',
#    'post_code': '15007',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 6,
#    'ebikes': 1,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'daa753bf3bdb6d5b722734d126b843b1',
#   'name': 'Plaza de Vigo',
#   'latitude': 43.361634,
#   'longitude': -8.407152,
#   'timestamp': '2024-12-17T22:09:32.127918Z',
#   'free_bikes': 7,
#   'empty_slots': 10,
#   'extra': {'uid': '13',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473346,
#    'address': 'Emilia Pardo Bazán 28-30',
#    'post_code': '15005',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 19,
#    'normal_bikes': 7,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'e97735d79704dc080f7ee1a2af1e402f',
#   'name': 'Obelisco',
#   'latitude': 43.3682065,
#   'longitude': -8.4032216,
#   'timestamp': '2024-12-17T22:09:32.127625Z',
#   'free_bikes': 1,
#   'empty_slots': 20,
#   'extra': {'uid': '7',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473325,
#    'address': 'Rúa Cantón Grande, 4',
#    'post_code': '15003',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 23,
#    'normal_bikes': 1,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'f04ee4ffca2a6f3daacba88a9eee8487',
#   'name': 'Millenium',
#   'latitude': 43.3768118,
#   'longitude': -8.423091,
#   'timestamp': '2024-12-17T22:09:32.128695Z',
#   'free_bikes': 10,
#   'empty_slots': 4,
#   'extra': {'uid': '56',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734471995,
#    'address': 'Av. Gerardo Porto ',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 10,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'f702a7b2b1631ace3781c405acb99b70',
#   'name': 'Praza de Ourense',
#   'latitude': 43.3651583,
#   'longitude': -8.4053212,
#   'timestamp': '2024-12-17T22:09:32.128463Z',
#   'free_bikes': 6,
#   'empty_slots': 9,
#   'extra': {'uid': '41',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473296,
#    'address': 'Praza Ourense, 3  ',
#    'post_code': '15004',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 6,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'f86954a7b51703f735bce5b549cb4e16',
#   'name': 'Parque del Agra',
#   'latitude': 43.36514,
#   'longitude': -8.421649,
#   'timestamp': '2024-12-17T22:09:32.128534Z',
#   'free_bikes': 0,
#   'empty_slots': 15,
#   'extra': {'uid': '45',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473226,
#    'address': 'Calle Canceliña,8',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 0,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'fb0d3f40ea7570546b171b43ccd57a2a',
#   'name': 'Rosales-Labañou',
#   'latitude': 43.37409724254996,
#   'longitude': -8.42479703248882,
#   'timestamp': '2024-12-17T22:09:32.128549Z',
#   'free_bikes': 7,
#   'empty_slots': 8,
#   'extra': {'uid': '46',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473252,
#    'address': 'Rúa Manuel Azaña,2',
#    'post_code': '15011',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 7,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}},
#  {'id': 'fee1ae73b32ffb83e1bf3f6e83e616b7',
#   'name': 'Centro Cívico Monelos',
#   'latitude': 43.3493537,
#   'longitude': -8.4049558,
#   'timestamp': '2024-12-17T22:09:32.128057Z',
#   'free_bikes': 9,
#   'empty_slots': 6,
#   'extra': {'uid': '21',
#    'renting': True,
#    'returning': True,
#    'last_updated': 1734473186,
#    'address': 'Av. Salvador de Madariaga, 2T',
#    'post_code': '15008',
#    'payment': ['key', 'transitcard', 'creditcard', 'phone'],
#    'payment-terminal': True,
#    'altitude': 0.0,
#    'slots': 15,
#    'normal_bikes': 9,
#    'ebikes': 0,
#    'has_ebikes': True,
#    'rental_uris': {}}}]

# %%
# Configuración da conexión á base de datos MongoDB
client = pymongo.MongoClient("mongodb://localhost:27017/")
db = client["bicicoruña"]
collection = db["Estaciones"]

# %%
# Función para almacenar datos na base de datos
def almacenar_datos_mongodb(datos):
    if datos:
        if isinstance(datos, list):  # Comproba se os datos son unha lista
            for dato in datos:
                if isinstance(dato, dict):  # Comproba se cada item é un diccionario
                    dato['timestamp'] = datetime.utcnow()  # Asigna o timestamp
                    collection.insert_one(dato)
            print("Datos almacenados correctamente.")
        else:
            print("Os datos non están no formato esperado.")
    else:
        print("Non se almacenaron datos.")

almacenar_datos_mongodb(datos)
# Out:
# /tmp/ipykernel_7286/68092162.py:7: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   dato['timestamp'] = datetime.utcnow()  # Asigna o timestamp
